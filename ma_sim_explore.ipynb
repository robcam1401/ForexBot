# %%
import pandas as pd
import plotly.graph_objects as go

# %%
ma_test_res = pd.read_pickle("ma_test_res.pkl")
all_trades = pd.read_pickle("all_trades.pkl")

# %%
all_trades.shape
# Out:
# (88747, 11)

# %%
ma_test_res.shape
# Out:
# (840, 8)

# %%
ma_test_res.head()
# Out:
#       pair  num_trades  total_gain  mean_gain  min_gain  max_gain  mashort
# 0  GBP_USD         536       896.0   1.671642    -221.2     246.9        4  \
# 1  GBP_USD         324     -1380.8  -4.261728    -232.8     264.9        4
# 2  GBP_USD         289       181.9   0.629412    -176.1     304.9        8
# 3  GBP_USD         206      -201.2  -0.976699    -156.0     314.2        4
# 4  GBP_USD         154      -467.8  -3.037662    -157.1     316.6        8
#
#    malong
# 0       8
# 1      16
# 2      16
# 3      32
# 4      32

# %%
ma_test_res.columns
# Out:
# Index(['pair', 'num_trades', 'total_gain', 'mean_gain', 'min_gain', 'max_gain',
#        'mashort', 'malong'],
#       dtype='object')

# %%
ma_test_res = ma_test_res[['pair', 'num_trades', 'total_gain', 'mashort', 'malong']]

# %%
ma_test_res["CROSS"] = "MA_" + ma_test_res.mashort.map(str) + "_" + ma_test_res.malong.map(str)

# %%
df_all_gains = ma_test_res.groupby(by=["CROSS" , "mashort", "malong"], as_index=False).sum()

# %%
df_all_gains.sort_values(by="total_gain", ascending=False, inplace=True)

# %%
df_all_gains.head()
# Out:
#       CROSS  mashort  malong
# 25  MA_8_16        8      16  \
# 15  MA_4_16        4      16
# 27  MA_8_32        8      32
# 17  MA_4_32        4      32
# 19   MA_4_8        4       8
#
#                                                  pair  num_trades  total_gain
# 25  GBP_USDGBP_CADGBP_JPYGBP_NZDGBP_CHFGBP_AUDEUR_...        7607      1429.6
# 15  GBP_USDGBP_CADGBP_JPYGBP_NZDGBP_CHFGBP_AUDEUR_...        8696     -7250.0
# 27  GBP_USDGBP_CADGBP_JPYGBP_NZDGBP_CHFGBP_AUDEUR_...        4241     -7714.2
# 17  GBP_USDGBP_CADGBP_JPYGBP_NZDGBP_CHFGBP_AUDEUR_...        5418     -8427.8
# 19  GBP_USDGBP_CADGBP_JPYGBP_NZDGBP_CHFGBP_AUDEUR_...       15391     -8910.8

# %%
ma_8_16 = ma_test_res[ma_test_res.CROSS=='MA_8_16'].copy()

# %%
ma_8_16.sort_values(by="total_gain", ascending=False, inplace=True)

# %%
total_p = len(ma_8_16.pair.unique())

# %%
ma_8_16[ma_8_16.total_gain>0].shape[0]
# Out:
# 14

# %%
14 / total_p
# Out:
# 0.5

# %%
for cross in df_all_gains.CROSS.unique():
    df_temp = ma_test_res[ma_test_res.CROSS==cross]
    total_p = df_temp.shape[0]
    n_good = df_temp[df_temp.total_gain>0].shape[0]
    print(f"{cross:12} {n_good:4} {(n_good/total_p)*100:4.0f}%")
# Out:
# MA_8_16        14   50%
# MA_4_16         8   29%
# MA_8_32         9   32%
# MA_4_32         7   25%
# MA_4_8          6   21%
# MA_16_32        6   21%
# MA_32_256       6   21%
# MA_64_256       6   21%
# MA_8_256        7   25%
# MA_8_64         9   32%
# MA_4_64         9   32%
# MA_16_256       5   18%
# MA_4_256        6   21%
# MA_24_32       10   36%
# MA_24_256       5   18%
# MA_64_96        4   14%
# MA_8_96         6   21%
# MA_4_96         6   21%
# MA_16_64        4   14%
# MA_24_64        2    7%
# MA_64_128       3   11%
# MA_16_96        3   11%
# MA_8_128        2    7%
# MA_4_128        3   11%
# MA_32_64        4   14%
# MA_32_128       0    0%
# MA_16_128       0    0%
# MA_32_96        1    4%
# MA_24_96        0    0%
# MA_24_128       0    0%

# %%
crosses = df_all_gains.CROSS.unique()[:3]

# %%
df_good = ma_test_res[(ma_test_res.CROSS.isin(crosses)) & (ma_test_res.total_gain>0)].copy()

# %%
our_pairs = list(df_good.pair.value_counts()[:5].index)

# %%
all_trades["CROSS"] = "MA_" + all_trades.MASHORT.map(str) + "_" + all_trades.MALONG.map(str)

# %%
all_trades.head(2)
# Out:
#                         time    mid_c      DIFF  DIFF_PREV  IS_TRADE  DELTA
# 22 2022-10-13 02:00:00+00:00  1.10832 -0.000016   0.000214        -1   63.8  \
# 29 2022-10-13 09:00:00+00:00  1.11470  0.000907  -0.000109         1  181.8
#
#      GAIN     PAIR  MASHORT  MALONG  DURATION   CROSS
# 22  -63.8  GBP_USD        4       8       7.0  MA_4_8
# 29  181.8  GBP_USD        4       8      13.0  MA_4_8

# %%
trades_cad_jpy = all_trades[(all_trades.CROSS=="MA_8_16") & (all_trades.PAIR=="CAD_JPY")].copy()

# %%
trades_cad_jpy.head()
# Out:
#                         time    mid_c      DIFF  DIFF_PREV  IS_TRADE  DELTA
# 19 2022-10-12 23:00:00+00:00  106.217 -0.011250   0.041938        -1   17.9  \
# 29 2022-10-13 09:00:00+00:00  106.396  0.002063  -0.011000         1  -61.4
# 32 2022-10-13 12:00:00+00:00  105.782 -0.008437   0.014687        -1  127.6
# 35 2022-10-13 15:00:00+00:00  107.058  0.022063  -0.021250         1    5.8
# 57 2022-10-14 13:00:00+00:00  107.116 -0.019125   0.022250        -1   16.4
#
#      GAIN     PAIR  MASHORT  MALONG  DURATION    CROSS
# 19  -17.9  CAD_JPY        8      16      10.0  MA_8_16
# 29  -61.4  CAD_JPY        8      16       3.0  MA_8_16
# 32 -127.6  CAD_JPY        8      16       3.0  MA_8_16
# 35    5.8  CAD_JPY        8      16      22.0  MA_8_16
# 57  -16.4  CAD_JPY        8      16      58.0  MA_8_16

# %%
trades_cad_jpy['CUM_GAIN'] = trades_cad_jpy.GAIN.cumsum()

# %%
def plot_line(df_plot,name):
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df_plot.time, 
        y=df_plot.CUM_GAIN,
        line=dict( width=2,color="#3d825f"),
        line_shape='spline',
        name=name,
        mode='lines'
        ))
    fig.update_layout(width=1000,height=400,
        margin=dict(l=15,r=15,b=10), 
        font = dict(size=10,color="#e1e1e1"),
        paper_bgcolor='#1e1e1e', 
        plot_bgcolor='#1e1e1e',
        title=name      
        )
    fig.update_xaxes(
        linewidth=1,
        linecolor='#3a4a54',
        showgrid=False,
        zeroline=False
    )
    fig.update_yaxes(
        linewidth=1,
        linecolor='#3a4a54',
        showgrid=False,
        zeroline=False
    )
    fig.show()

# %%
plot_line(trades_cad_jpy,"CAD_JPY")

# %%
c = 'MA_8_16'
for p in our_pairs:
    temp_df = all_trades[(all_trades.CROSS==c)&(all_trades.PAIR==p)].copy()
    temp_df['CUM_GAIN'] = temp_df.GAIN.cumsum()
    plot_line(temp_df, p + "_" + c)

# %%
for c in crosses:
    temp_df = all_trades[(all_trades.CROSS==c)].copy()
    temp_df = temp_df.groupby(by="time", as_index=False).sum()
    temp_df['CUM_GAIN'] = temp_df.GAIN.cumsum()
    plot_line(temp_df, c)

# %%
# Out:
#                        time      mid_c      DIFF  DIFF_PREV  IS_TRADE  DELTA
# 0 2022-10-12 22:00:00+00:00    1.34168  0.000420  -0.000069         1    3.0  \
# 1 2022-10-12 23:00:00+00:00  106.93898 -0.011339   0.042169        -2   31.7
# 2 2022-10-13 00:00:00+00:00  148.22946 -0.004479   0.002327         0   -7.1
# 3 2022-10-13 02:00:00+00:00  146.85500 -0.000562   0.021750        -1   -2.7
# 4 2022-10-13 03:00:00+00:00    0.99804 -0.000073   0.000076        -1   12.2
# 5 2022-10-13 04:00:00+00:00    3.52150 -0.000014  -0.000071         0  247.6
# 6 2022-10-13 05:00:00+00:00  313.69527 -0.002121   0.066371        -1  240.2
# 7 2022-10-13 06:00:00+00:00  149.69600 -0.014039   0.002961        -3  151.8
# 8 2022-10-13 07:00:00+00:00    2.53110 -0.000138   0.000076         0   99.2
# 9 2022-10-13 08:00:00+00:00  291.15275 -0.012431  -0.009661         0   41.5
#
#     GAIN                                 PAIR  MASHORT  MALONG  DURATION
# 0    3.0                              EUR_CAD        8      16      11.0  \
# 1  -31.7                       CAD_JPYCAD_CHF       16      32      19.0
# 2    5.7                       EUR_USDCHF_JPY       16      32      13.0
# 3    2.7                              USD_JPY        8      16       6.0
# 4  -12.2                              USD_CHF        8      16       4.0
# 5 -261.6                       GBP_NZDEUR_AUD       16      32       9.0
# 6 -336.6  GBP_JPYGBP_CHFGBP_AUDEUR_GBPCHF_JPY       40      80      20.0
# 7 -151.8                GBP_USDEUR_AUDCHF_JPY       24      48      21.0
# 8  -63.8                       GBP_CADUSD_CHF       16      32      18.0
# 9   -9.1         EUR_USDEUR_JPYUSD_JPYCAD_CHF       32      64      30.0
#
#                                  CROSS
# 0                              MA_8_16
# 1                       MA_8_16MA_8_16
# 2                       MA_8_16MA_8_16
# 3                              MA_8_16
# 4                              MA_8_16
# 5                       MA_8_16MA_8_16
# 6  MA_8_16MA_8_16MA_8_16MA_8_16MA_8_16
# 7                MA_8_16MA_8_16MA_8_16
# 8                       MA_8_16MA_8_16
# 9         MA_8_16MA_8_16MA_8_16MA_8_16
